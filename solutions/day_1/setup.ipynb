# %% [markdown]
# # Setup for Advent of Code
#
# Set custom user variables to auto-generate folders and files for any year of Advent of Code.
#
# You should only run this module for two reasons:
#
# - When you start a new Advent of Code event, or
#
# - When you change the path of your Advent of Code project folders.
#
# The Markdown cells below indicate  depending on your reason for running this module.
#
# *Note: it is not recommended to change the default file structure generated by this module (pictured below).*
#
# ## Project File Tree
#
# The pictured file tree is assumed to be located within your own user-defined root directory.
#
# For example, my `Advent-of-Code-2023` folder is placed within my `/home/lilyroses/AoC/` folder.
#
# You can set the variable for your project's root directory in the `setup.ipynb` module (this module) below in the user-defined variables section.
#
# ```
# ...
# |__ Advent-of-Code-2023
#     |__ solutions
#         |__ day_1
#             |__ solution.ipynb
#             |__ instructions.md
#             |__ input.txt
#         |__ day_2
#             |__ solution.ipynb
#             |__ instructions.md
#             |__ input.txt
#         ...
#         |__ day_n
#             |__ solution.ipynb
#             |__ instructions.md
#             |__ input.txt
# ```

# %% [markdown]
# ---

# %% [markdown]
# ## User-Defined Variables
#
# - `PROJECT_DIR` variable : Set the directory path where your `Advent-of-Code-2023` project folder will reside.
#
# - `YEAR` variable : Specify the year of the Advent of Code event.

# %%
# User-Defined Root Directory
PROJECT_DIR = '/home/lilyroses/code/AoC/'

# %%
# The Year of the Advent of Code event
YEAR = 2023

# %% [markdown]
# ---
#
# ## END USER-DEFINED VARIABLES
#
# Do not alter the code cells beyond this point.
#
# If an error message occurs after running this notebook, inspect the error output and make changes accordingly.

# %%
import os

try:
